# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bb = pd.read_csv('../input/bureau_balance.csv')

# %%
bb_copy = bb.copy()

# %%
bb.head()
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
bb.isnull().sum(), len(bb)
# Out:
# (SK_ID_BUREAU      0
#  MONTHS_BALANCE    0
#  STATUS            0
#  dtype: int64, 27299925)

# %%
plt.hist(bb['MONTHS_BALANCE'])
# Out:
# (array([ 597242., 1005721., 1169545., 1578749., 1853676., 2687080.,
#         3466576., 3823688., 5122517., 5995131.]),
#  array([-96. , -86.4, -76.8, -67.2, -57.6, -48. , -38.4, -28.8, -19.2,
#          -9.6,   0. ]),
#  <a list of 10 Patch objects>)

# %%
bb['STATUS'].value_counts()
# Out:
# C    13646993
# 0     7499507
# X     5810482
# 1      242347
# 5       62406
# 2       23419
# 3        8924
# 4        5847
# Name: STATUS, dtype: int64

# %%
bb[bb.STATUS == 'C'].head(10)
# Out:
#     SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0        5715448               0      C
# 1        5715448              -1      C
# 2        5715448              -2      C
# 3        5715448              -3      C
# 4        5715448              -4      C
# 5        5715448              -5      C
# 6        5715448              -6      C
# 7        5715448              -7      C
# 8        5715448              -8      C
# 27       5715449               0      C

# %%
bb[bb.STATUS == 'X'].head(10)
# Out:
#     SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 11       5715448             -11      X
# 12       5715448             -12      X
# 13       5715448             -13      X
# 20       5715448             -20      X
# 21       5715448             -21      X
# 22       5715448             -22      X
# 23       5715448             -23      X
# 24       5715448             -24      X
# 25       5715448             -25      X
# 26       5715448             -26      X

# %%
bb[bb.STATUS == '0'].head(10)
# Out:
#     SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 9        5715448              -9      0
# 10       5715448             -10      0
# 14       5715448             -14      0
# 15       5715448             -15      0
# 16       5715448             -16      0
# 17       5715448             -17      0
# 18       5715448             -18      0
# 19       5715448             -19      0
# 33       5715449              -6      0
# 34       5715449              -7      0

# %%
bb[bb.STATUS == '1'].head(10)
# Out:
#      SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 464       5715793             -39      1
# 465       5715793             -40      1
# 468       5715793             -43      1
# 499       5715795             -30      1
# 500       5715795             -31      1
# 503       5715795             -34      1
# 527       5715796             -29      1
# 528       5715796             -30      1
# 531       5715796             -33      1
# 537       5715797              -1      1

# %%
bb[bb.STATUS == '2'].head(10)
# Out:
#        SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 543         5715797              -7      2
# 550         5715797             -14      2
# 9006        5719805             -85      2
# 9088        5719811             -37      2
# 9406        5719836             -82      2
# 9407        5719836             -83      2
# 9490        5719837             -74      2
# 9493        5719837             -77      2
# 10232       5720038             -47      2
# 13962       5212230             -64      2

# %%
bb[bb.STATUS == '3'].head(10)
# Out:
#        SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 9005        5719805             -84      3
# 9492        5719837             -76      3
# 29369       5230570             -81      3
# 29370       5230570             -82      3
# 29371       5230570             -83      3
# 29833       5230719             -40      3
# 30247       5230729             -40      3
# 31847       5231215             -47      3
# 31848       5231215             -48      3
# 31849       5231215             -49      3

# %%
bb[bb.STATUS == '4'].head(10)
# Out:
#        SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 29368       5230570             -80      4
# 29832       5230719             -39      4
# 30245       5230729             -38      4
# 30246       5230729             -39      4
# 31846       5231215             -46      4
# 52229       6021273             -62      4
# 52230       6021273             -63      4
# 52231       6021273             -64      4
# 52232       6021273             -65      4
# 52233       6021273             -66      4

# %%
bb[bb.STATUS == '5'].head(10)
# Out:
#        SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 29354       5230570             -66      5
# 29355       5230570             -67      5
# 29356       5230570             -68      5
# 29357       5230570             -69      5
# 29358       5230570             -70      5
# 29359       5230570             -71      5
# 29360       5230570             -72      5
# 29361       5230570             -73      5
# 29362       5230570             -74      5
# 29363       5230570             -75      5

# %%
"""
ToDo
SK_ID_BUREAU -> IDの被りをどう扱う？
MONTHS_BALANCE -> 時系列データ？
STATUS -> X, C, 0~5 -> X,Cはなに？

他のデータとの関連性見たほうがいい！
"""
# Out:
# '\nToDo\nSK_ID_BUREAU -> IDの被りをどう扱う？\nMONTHS_BALANCE -> 時系列データ？\nSTATUS -> X, C, 0~5 -> X,Cはなに？\n\n他のデータとの関連性見たほうがいい！\n'
